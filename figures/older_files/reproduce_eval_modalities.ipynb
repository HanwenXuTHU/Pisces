# %%
from fig_utils import *
source_data_path = '/home/swang/xuhw/research-projects/Pisces/figures/data/source_data.xlsx'
m2bacc, m2auprc, m2f1, m2kappa = load_gdsc_trans_eval_modalities(source_data_path)
gdsc_df = load_gdsc_data(source_data_path)
bacc_tgt, bacc_tgt_err = np.mean(np.asarray(gdsc_df['BACC'])[0, 0: 3]), np.std(np.asarray(gdsc_df['BACC'])[0, 0: 3])
gdsc_eval_modalities_plot(m2bacc, bacc_tgt, bacc_tgt_err, 'BACC', '.png')

auprc_tgt, auprc_tgt_err = np.mean(np.asarray(gdsc_df['AUPRC'])[0, 0: 3]), np.std(np.asarray(gdsc_df['AUPRC'])[0, 0: 3])
gdsc_eval_modalities_plot(m2auprc, auprc_tgt, auprc_tgt_err, 'AUPRC', '.png')

f1_tgt, f1_tgt_err = np.mean(np.asarray(gdsc_df[r'$F_1$'])[0, 0: 3]), np.std(np.asarray(gdsc_df[r'$F_1$'])[0, 0: 3])
gdsc_eval_modalities_plot(m2f1, f1_tgt, f1_tgt_err, r'$F_1$', '.png')

kappa_tgt, kappa_tgt_err = np.mean(np.asarray(gdsc_df['KAPPA'])[0, 0: 3]), np.std(np.asarray(gdsc_df['KAPPA'])[0, 0: 3])
gdsc_eval_modalities_plot(m2kappa, kappa_tgt, kappa_tgt_err, 'KAPPA', '.png')
